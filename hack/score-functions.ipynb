# %%
import math

# mem_g=[1,2,5,8,10,15,20,32,40,50,60]
mem_g = [i for i in range(1,100)]

# %% [markdown]
# ## sigmoid

# %%
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
list(zip(mem_g ,list(map(lambda x:sigmoid(x/10),mem_g))))
# Out:
# [(1, 0.52497918747894),
#  (2, 0.549833997312478),
#  (3, 0.574442516811659),
#  (4, 0.598687660112452),
#  (5, 0.6224593312018546),
#  (6, 0.6456563062257954),
#  (7, 0.6681877721681662),
#  (8, 0.6899744811276125),
#  (9, 0.7109495026250039),
#  (10, 0.7310585786300049),
#  (11, 0.7502601055951177),
#  (12, 0.7685247834990175),
#  (13, 0.7858349830425586),
#  (14, 0.8021838885585817),
#  (15, 0.8175744761936437),
#  (16, 0.8320183851339245),
#  (17, 0.8455347349164652),
#  (18, 0.8581489350995123),
#  (19, 0.8698915256370021),
#  (20, 0.8807970779778823),
#  (21, 0.8909031788043871),
#  (22, 0.9002495108803148),
#  (23, 0.9088770389851438),
#  (24, 0.9168273035060777),
#  (25, 0.9241418199787566),
#  (26, 0.9308615796566533),
#  (27, 0.9370266439430035),
#  (28, 0.9426758241011313),
#  (29, 0.9478464369215823),
#  (30, 0.9525741268224334),
#  (31, 0.9568927450589139),
#  (32, 0.9608342772032357),
#  (33, 0.9644288107273639),
#  (34, 0.9677045353015494),
# ...
